# %%
import pandas as pd
import numpy as np

# Machine learning pipeline
from sklearn.model_selection import train_test_split
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import LogisticRegression
#from xgboost import XGBClassifier

from sklearn.metrics import f1_score

# %%
#train_values
train_values = pd.read_csv(r"C:\Users\olami\Downloads\train_values.csv")
train_values
# Out:
#         building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0            802906               6             487           12198
# 1             28830               8             900            2812
# 2             94947              21             363            8973
# 3            590882              22             418           10694
# 4            201944              11             131            1488
# ...             ...             ...             ...             ...
# 260596       688636              25            1335            1621
# 260597       669485              17             715            2060
# 260598       602512              17              51            8163
# 260599       151409              26              39            1851
# 260600       747594              21               9            9101
#
#         count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                         2   30                6                  5
# ...

# %%
#train_labels
train_labels = pd.read_csv(r"C:\Users\olami\Downloads\train_labels.csv")
train_labels
# Out:
#         building_id  damage_grade
# 0            802906             3
# 1             28830             2
# 2             94947             3
# 3            590882             2
# 4            201944             3
# ...             ...           ...
# 260596       688636             2
# 260597       669485             3
# 260598       602512             3
# 260599       151409             2
# 260600       747594             3
#
# [260601 rows x 2 columns]

# %%
#-----------Understanding the data----------#

print('Count of target variables:')
print(train_labels.damage_grade.value_counts()) #Count of target variables

print('\nCount of feature values:') #Count of feature values
print(train_values.nunique())

print('\nData type of features and target:')
print(train_values.dtypes)#gets the data type of each column

print('\nColumn names:')
print(train_values.columns) #get Column names

print("\nNull values?", train_values.isnull().values.all()) #checks if the data has null values
#print(train_data.isnull().sum())

print("\nSummary statistics of the data:")
train_values.describe() #gets summary statistics of the data
# Out:
# Count of target variables:
# 2    148259
# 3     87218
# 1     25124
# Name: damage_grade, dtype: int64
#
# Count of feature values:
# building_id                               260601
# geo_level_1_id                                31
# geo_level_2_id                              1414
# geo_level_3_id                             11595
# count_floors_pre_eq                            9
# age                                           42
# area_percentage                               84
# height_percentage                             27
# land_surface_condition                         3
# foundation_type                                5
# roof_type                                      3
# ground_floor_type                              5
# other_floor_type                               4
# position                                       4
# plan_configuration                            10
# has_superstructure_adobe_mud                   2
# ...

# %% [markdown]
# No missing data and values match the data description

# %%
#--------Separate categorical and numeric features so they can be preprocessed-----------#

building_id = 'building_id'
train_features = train_values.columns.drop(building_id) #dropping the building id as the model cannot learn anything from it


#numeric variables
NUMERICAL = train_values[train_features].select_dtypes('number').columns
print(f"Numerical features: {', '.join(NUMERICAL)}")

#categorical variables
CATEGORICAL = pd.Index(np.setdiff1d(train_features, NUMERICAL))
print(f"\nCategorical features: {', '.join(CATEGORICAL)}")
# Out:
# Numerical features: geo_level_1_id, geo_level_2_id, geo_level_3_id, count_floors_pre_eq, age, area_percentage, height_percentage, has_superstructure_adobe_mud, has_superstructure_mud_mortar_stone, has_superstructure_stone_flag, has_superstructure_cement_mortar_stone, has_superstructure_mud_mortar_brick, has_superstructure_cement_mortar_brick, has_superstructure_timber, has_superstructure_bamboo, has_superstructure_rc_non_engineered, has_superstructure_rc_engineered, has_superstructure_other, count_families, has_secondary_use, has_secondary_use_agriculture, has_secondary_use_hotel, has_secondary_use_rental, has_secondary_use_institution, has_secondary_use_school, has_secondary_use_industry, has_secondary_use_health_post, has_secondary_use_gov_office, has_secondary_use_use_police, has_secondary_use_other
#
# Categorical features: foundation_type, ground_floor_type, land_surface_condition, legal_ownership_status, other_floor_type, plan_configuration, position, roof_type

# %%
#-------------Split the dataset into Train and Validation set--------------#

SEED = 42

X_train, X_validation, y_train, y_validation = train_test_split(train_values, train_labels['damage_grade'], 
                                                                test_size=.2, random_state=SEED, 
                                                                stratify=train_labels['damage_grade'])

# %%
#------------Preprocessing and Model Pipeline-----------#

numerical_pipe = Pipeline([ ('imputer', SimpleImputer(strategy='mean')),
                            ('scaler', MinMaxScaler())
                         ])

categorical_pipe = Pipeline([ ('imputer', SimpleImputer(strategy='constant', fill_value='missing')),
                              ('encoder', OneHotEncoder(drop='first', handle_unknown='ignore', sparse=False))
                         ])

preprocessors = ColumnTransformer(transformers=[ ('num', numerical_pipe, NUMERICAL),
                                                 ('cat', categorical_pipe, CATEGORICAL)
                                 ])

pipe = Pipeline([ ('preprocessors', preprocessors),
                  ('model', LogisticRegression(max_iter=1000))
                ])

# %%
#train Model

pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('preprocessors',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('scaler',
#                                                                    MinMaxScaler())]),
#                                                   Index(['geo_level_1_id', 'geo_level_2_id', 'geo_level_3_id',
#        'count_floors_pre_eq', 'age', 'area_percentage', 'height_percentage',
#        'has_superstructure_adobe_mud', 'has_superstructure_mud_mortar_stone',
#        'has_superstr...
#                                                                    SimpleImputer(fill_value='missing',
#                                                                                  strategy='constant')),
# ...

# %%
#--------Performance Scoring---------#

y_pred = pipe.predict(X_validation)

f1_score(y_validation, y_pred, average='micro')
# Out:
# 0.5917960131233092

# %%
pipe.score(X_validation, y_validation)
# Out:
# 0.5917960131233092

# %%
#---------Load Test dataset----------#

test = pd.read_csv(r"C:\Users\olami\Downloads\test_values.csv")
test
# Out:
#        building_id  geo_level_1_id  geo_level_2_id  geo_level_3_id  \
# 0           300051              17             596           11307
# 1            99355               6             141           11987
# 2           890251              22              19           10044
# 3           745817              26              39             633
# 4           421793              17             289            7970
# ...            ...             ...             ...             ...
# 86863       310028               4             605            3623
# 86864       663567              10            1407           11907
# 86865      1049160              22            1136            7712
# 86866       442785               6            1041             912
# 86867       501372              26              36            6436
#
#        count_floors_pre_eq  age  area_percentage  height_percentage  \
# 0                        3   20                7                  6
# ...

# %%
Pred_test = pipe.predict(test)

# %%
# #------------Prediction submission for DrivenData------------#

# Pred_test_df = pd.DataFrame(Pred_test) #prediction to DataFrame
# submission = pd.concat([test['building_id'], Pred_test_df], axis=1)

# %%
# submission.rename(columns = {0:'damage_grade'}, inplace=True)
# submission.to_csv(r"C:\Users\olami\Downloads\submission2.csv", index=False)

# %%
# sub = pd.read_csv(r"C:\Users\olami\Downloads\submission2.csv")
# sub
# Out:
#        building_id  damage_grade
# 0           300051             2
# 1            99355             2
# 2           890251             2
# 3           745817             2
# 4           421793             3
# ...            ...           ...
# 86863       310028             2
# 86864       663567             3
# 86865      1049160             2
# 86866       442785             2
# 86867       501372             2
#
# [86868 rows x 2 columns]
